# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
    def product_details(self):
        print("Product:",self.name)
        print("Price:$",self.price)
details=Product("HeadPhones",2499)
details.product_details()
# Out:
# Product: HeadPhones
# Price:$ 2499
