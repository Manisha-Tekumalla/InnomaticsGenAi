# %%
class Movie:
    def __init__(self,name,rating):
        self.name=name
        self.rating=rating
    def display_movie(self):
        print(f"Movie Rating:{self.name}")
        print(f"Rating:{self.rating}/5")
movie= Movie("Inception",4.8)
movie.display_movie()
# Out:
# Movie Rating:Inception
# Rating:4.8/5
